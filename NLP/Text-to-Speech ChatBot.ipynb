# %% [markdown]
# # Install pyttsx3 for Text-to-Speech Convertion

# %%
pip install SpeechRecognition pyttsx3  pyaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install newsapi-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Source Code :

# %%
import pyttsx3
import datetime
import random
import webbrowser
import requests
from bs4 import BeautifulSoup
from newsapi import NewsApiClient


# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Function to convert text to speech
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to get the current time
def get_time():
    now = datetime.datetime.now()
    return now.strftime("%H:%M:%S")

# Function to get the current date
def get_date():
    today = datetime.date.today()
    return today.strftime("%B %d, %Y")

# Function to tell a random joke
def tell_joke():
    jokes = [
        "Why don't scientists trust atoms? Because they make up everything!",
        "Why did the scarecrow win an award? Because he was outstanding in his field!",
        "What do you call fake spaghetti? An impasta!",
        "Why did the bicycle fall over? It was two tired!",
    ]
    return random.choice(jokes)



# Function to get the latest news headlines
def get_latest_news():
    api_key = '9c0009db00c64b6e92fe21874582997f'
    newsapi = NewsApiClient(api_key='9c0009db00c64b6e92fe21874582997f')
    
    try:
        top_headlines = newsapi.get_top_headlines(language='en', country='us')
        articles = top_headlines['articles']
        
        if not articles:
            return "Sorry, I couldn't fetch the news. Please try again later."
        
        news = "Here are the latest news headlines:\n"
        for article in articles[:5]:  # Fetch top 5 headlines
            news += f"- {article['title']}\n"
        return news
    except requests.exceptions.ReadTimeout:
        return "The request timed out. Please try again later."
    except requests.exceptions.RequestException as e:
        return f"An error occurred: {e}"
    

# Function to stop Speaking
def stop_speaking():
    engine.stop()

# Function for weather Forecast

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
def weather(city):
    city=city.replace(" ","+")
    res=requests.get(
                f'https://www.google.com/search?q={city}&oq={city}&aqs=chrome.0.35i39l2j0l4j46j69i60.6128j1j7&sourceid=chrome&ie=UTF-8', headers=headers)
    soup=BeautifulSoup(res.text,'html.parser')
    try:
        location = soup.select('#wob_loc')[0].getText().strip()
        info = soup.select('#wob_dc')[0].getText().strip()
        temperature = soup.select('#wob_tm')[0].getText().strip()
        return f"Location: {location}\nCurrently the Weather is : {info}\nTemperature: {temperature}°C"
    except IndexError:
        return "Sorry, I couldn't fetch the weather information. Please try again later."
    
# Function to open a website
def open_website(site_name):
    websites = {
        "google": "https://www.google.com",
        "youtube": "https://www.youtube.com",
        "github": "https://www.github.com",
    }
    url = websites.get(site_name.lower(), None)
    if url:
        webbrowser.open(url)
        return f"Opening {site_name}"
    else:
        return "I don't know that website."

# Function to provide a help menu
def get_help():
    commands = (
        "Here are some things you can ask me:\n"
        "- Say hello\n"
        "- Ask for the time or date\n"
        "- Request a joke\n"
        "- Ask about me\n"
        "- Open websites like Google, YouTube, or GitHub\n"
        "- Say goodbye to exit"
    )
    return commands

# Main function to handle user commands
def main():
    speak("Hello! I am your personal bot. How can I assist you today?")

    while True:
        command = input("You: ").lower()

        if "hello" in command:
            speak("Hi there! How can I help you?")
        elif "how are you" in command:
            speak("I'm just a bot, but I'm here to help you! How about you?")
        elif "what's your name" in command or "who are you" in command:
            speak("I'm your personal bot, here to assist you with anything I can.")
        elif "time" in command:
            current_time = get_time()
            speak(f"The current time is {current_time}.")
            print(current_time)
        elif "date" in command:
            current_date = get_date()
            speak(f"Today's date is {current_date}.")
        elif "joke" in command:
            joke = tell_joke()
            speak(joke)
        elif "news"in command:
            news = get_latest_news()
            print(news)
            speak(news)
            
        elif "weather" in command:
            speak("Please , tell me the name of the city: ")
            city=input()
            weather_info=weather(city)
            print(weather_info)
            speak(weather_info)
        elif "help" in command:
            help_text = get_help()
            speak(help_text)
            print(help_text)
        elif "open" in command:
            site_name = command.replace("open", "").strip()
            response = open_website(site_name)
            speak(response)
        elif "bye" in command or "exit" in command or "quit" in command:
            speak("Goodbye! Have a great day!")
            break
        elif "stop" in command:
            stop_speaking()
            speak("OK")
        else:
            speak("I didn't quite catch that. Could you please repeat?")

if __name__ == "__main__":
    main()
# Out:
# You: hello
# You: help
# Here are some things you can ask me:
# - Say hello
# - Ask for the time or date
# - Request a joke
# - Ask about me
# - Open websites like Google, YouTube, or GitHub
# - Say goodbye to exit
# You: how are you
# You: open google
# You: open youtube
# You: joke
# You: weather
# news
# Sorry, I couldn't fetch the weather information. Please try again later.
# You: news
# Here are the latest news headlines:
# - Palisades homes burn - LAist
# - Horry Scale: Trae Young beats buzzer, Jazz from beyond halfcourt - NBA.Com
# - Mark Zuckerberg sported a $900,000 piece of wrist candy as he announced the end of fact-checking on Meta - Business Insider
# - Trump declines to rule out ‘military or economic’ force to expand U.S. - The Washington Post
# - Two bodies found in wheel well of JetBlue flight in Fort Lauderdale - The Washington Post
#
# You: stop
# You: bye
